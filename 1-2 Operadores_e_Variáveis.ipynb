# %% [markdown]
# # Operadores Aritméticos

# %%
# Adição
10 + 2
# Out:
# 12

# %%
#Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 2
# Out:
# 20

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão inteira
10 // 2
# Out:
# 5

# %%
# Resto da divisão
10 % 2
# Out:
# 0

# %%
# Potencição
10 ** 2
# Out:
# 100

# %% [markdown]
# # Operadores Relacionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# MAior ou igual
10 >= 2
# Out:
# True

# %%
# Igual
7 == 7
# Out:
# True

# %%
# Direferente
7 != 7
# Out:
# False

# %% [markdown]
# # Operadores Lógicos
#
# * And
# * Or
# * Not

# %% [markdown]
# # Tabela Verdade
# ## And

# %%
print(10 > 2 and 4 < 6) # V and V - V
print(10 > 2 and 4 > 6) # V and F - F
print(10 < 2 and 4 < 6) # V and F - F
print(10 < 2 and 4 > 6) # F and F - F
# Out:
# True
# False
# False
# False

# %% [markdown]
# ## Or

# %%
print(10 > 2 or 4 < 6) # V and V - V
print(10 > 2 or 4 > 6) # V and F - V
print(10 < 2 or 4 < 6) # V and F - V
print(10 < 2 or 4 > 6) # F and F - F
# Out:
# True
# True
# True
# False

# %% [markdown]
# ## Not

# %%
not 10 > 2 # V - F
# Out:
# False

# %%
not 10 < 2 # F - V
# Out:
# True

# %% [markdown]
# # Variáveis
# ## Variáveis estão alocadas em espaços na memória

# %%
# Nome da variável é "x" que armazena o valor 10 em um campo na memória
x = 10

print(x) # Utilizar a referencia no nome atribuido
# Out:
# 10

# %% [markdown]
# ## Regras

# %% [markdown]
# ## Case Sensitive

# %% [markdown]
# A !=a

# %% [markdown]
# ## Boas Práticas com Variáveis
#
# * Exemplo: Multiplicação de 2 números
#
# ## Não usar
#
# * Multiplicação
# * MultiplicaçãoDeDoisNumeros
# * m
#
# ## Usar
#
# * multiplicacao
# * mult
# * mult_total(anake_case)
#
# ## Tipos de Variáveis
#
# * Pythom é uma linguagem de alto nível
# * Não é necessário especificar o tipo de dados quando declarar a variável
# * Python defini o tipo de dados na declaração
#
# ## Int - num = 5
# ## Float num = 5.2
# ## String: meu_nome = "Rodrigo"
# ## Bool: booleana = 10 > 5 (V ou F)
